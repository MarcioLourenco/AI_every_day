# %% [markdown]
# ## AWS - MLOps for architects

# %% [markdown]
# ### 1 - 3 Data Scientists

# %% [markdown]
# ![image.png](attachment:309d9b35-39fe-454d-a5ec-49aed57239d0.png)

# %% [markdown]
# ### 3 - 10 Data Scientists

# %% [markdown]
# ![image.png](attachment:9867af34-37f5-4e3d-a404-fc0226a2d7a4.png)

# %% [markdown]
# ### 10 + Data Scientists

# %% [markdown]
# ![image.png](attachment:c794f782-cb06-4c3b-8e4c-ba0ae1f177fa.png)
