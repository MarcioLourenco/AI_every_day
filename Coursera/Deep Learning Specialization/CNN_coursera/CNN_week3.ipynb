# %% [markdown]
# ## Object Detection

# %% [markdown]
# ![image.png](attachment:5ae465e8-cb9a-4428-8a1c-fa671e7d15c4.png)

# %% [markdown]
# ![image.png](attachment:7b57db15-4ebd-4c8c-b2e6-d6cb3d872c8c.png)

# %% [markdown]
# ## Landmarks
# ![image.png](attachment:847775fc-d394-413e-a7f5-51992e882fd4.png)

# %% [markdown]
# ## Object Detection
# ![image.png](attachment:c153d06e-9ddb-4205-a307-4c002b466431.png)

# %% [markdown]
# ## Transformar Fully Conect Layer em Convoluional

# %% [markdown]
# ![image.png](attachment:31012a71-c512-4939-af83-cdc1744c768f.png)

# %% [markdown]
# ![image.png](attachment:7f57f56b-5647-42fe-a80f-8fd5f64fe6e1.png)

# %% [markdown]
# ## YOLO

# %% [markdown]
# ![image.png](attachment:7a10f5ba-8d22-4005-a1d5-b678a9344542.png)

# %% [markdown]
# ![image.png](attachment:10caab7a-000f-4542-b33a-9f32aac22aee.png)

# %% [markdown]
# ## Non max supression

# %% [markdown]
# ![image.png](attachment:cb76c571-d353-4ae8-b2fe-bb021381f262.png)

# %% [markdown]
# ![image.png](attachment:a5c9c746-f938-4046-bdd9-7f41e6bf7029.png)

# %% [markdown]
# ## YOLO

# %% [markdown]
# ![image.png](attachment:c7e85499-984a-4e94-b7c9-43c7d6cd4bef.png)

# %% [markdown]
# ## Image Segmentation

# %% [markdown]
# ![image.png](attachment:282b84ea-eb7e-4fec-9303-2ab87f9f470f.png)

# %% [markdown]
# ![image.png](attachment:de731f0a-a14f-4b00-b0c1-0c7fdde21b4c.png)

# %% [markdown]
# ![image.png](attachment:de394b8d-247c-4093-9be6-a2e2ee8a7bec.png)

# %% [markdown]
# ![image.png](attachment:4b2c7f5e-ec3e-4cf1-8521-8ef722fdd686.png)

# %% [markdown]
# ![image.png](attachment:c5fec45d-5a41-4c7e-867a-e31662bb4084.png)

# %% [markdown]
# ![image.png](attachment:f84da869-e123-4e56-89a9-18a00e0f6878.png)
