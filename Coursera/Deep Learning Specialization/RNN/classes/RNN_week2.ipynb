# %% [markdown]
# # NLP

# %% [markdown]
# ## Word Representation

# %% [markdown]
# ![image.png](attachment:c34d1e51-a4ba-4565-a78f-d85d60f44943.png)

# %% [markdown]
# ## Featurized representation

# %% [markdown]
# ![image.png](attachment:1d747b9d-b197-494d-b786-ac5c701cf4b7.png)

# %% [markdown]
# ![image.png](attachment:da324bda-c1b1-4eaa-bad5-2ee2393bbc47.png)

# %% [markdown]
# ## Using Word Embedding
# - Named entity recognition example

# %% [markdown]
# ![image.png](attachment:e3274c0d-f18c-4c6e-ad75-da399e42c348.png)

# %% [markdown]
# ## Analogies
# ![image.png](attachment:9ea0cdf3-303c-466d-a46e-8074cceb0ef5.png)

# %% [markdown]
# ![image.png](attachment:48271179-eee3-461f-8396-9a4ef60c7474.png)

# %% [markdown]
# ## Similarity Calculation

# %% [markdown]
# ![image.png](attachment:f2440667-de0d-4d20-997c-0069bc97adde.png)

# %% [markdown]
# ## Embedding Matrix
# ![image.png](attachment:5104ddeb-86a5-459b-b73d-67c3ea7ad814.png)

# %% [markdown]
# ## Learning Word Embeddings

# %% [markdown]
# ![image.png](attachment:957c5a76-7813-4f51-8ca9-3700d884d849.png)

# %% [markdown]
# ## Word2Vec
# - skip gram model
# - problem: computational cost of softmax
# - X (Embedding word)
# - Y (probability of vocab)
# - Final layer: Softmax (vocab)

# %% [markdown]
# ![image.png](attachment:31c15fe6-4798-49cc-8a7d-e129106198eb.png)

# %% [markdown]
# ## Negative sampling
# - X (context - word)
# - Y (0 or 1)
# - Final layer: Logistic Regression (binary target)

# %% [markdown]
# ![image.png](attachment:98db4d46-7933-4e9a-afee-0dad6d298722.png)

# %% [markdown]
# ![image.png](attachment:15a112ff-12bb-4a99-8690-af3b91a7991a.png)

# %% [markdown]
# ## GloVe - Global Vectors for word representation

# %% [markdown]
# ![image.png](attachment:fa6482bf-469b-4d47-904d-df1eff31a0fb.png)

# %% [markdown]
# ![image.png](attachment:2d62cfcd-06f4-487d-9878-3a27e46bc5c2.png)

# %% [markdown]
# ## Sentiment Classification

# %% [markdown]
# ![image.png](attachment:9334dd6e-0883-4255-a847-f85662501808.png)

# %% [markdown]
# ![image.png](attachment:2ad2996a-f21d-42f3-94a1-1cd7ce13d3be.png)

# %% [markdown]
# ![image.png](attachment:60098352-0aa1-4b99-a715-166abe79ba20.png)

# %% [markdown]
# ## Problems (bias)
# ![image.png](attachment:278c73fd-4c3a-4950-bfa7-baf6e29b6829.png)

# %% [markdown]
# ![image.png](attachment:f7a0b74c-3b57-4b92-b2b1-f566cd535c11.png)
