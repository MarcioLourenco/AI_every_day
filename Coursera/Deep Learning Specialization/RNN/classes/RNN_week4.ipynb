# %% [markdown]
# ## Transformers

# %% [markdown]
# ![image.png](attachment:b3533c92-4644-42c1-b6f9-7b65f9631e57.png)

# %% [markdown]
# ![image.png](attachment:68d48e7d-6f15-4022-ad03-c9527b66afe0.png)

# %% [markdown]
# ## Self Attention

# %% [markdown]
# ![image.png](attachment:85b0476e-0113-4ebb-81dd-a7475d926d26.png)

# %% [markdown]
# ![image.png](attachment:fff00724-8808-4938-bc16-03d85f0f521c.png)

# %% [markdown]
# ![image.png](attachment:fc2f0c5b-701b-49ba-8acf-6f463e0494bc.png)

# %% [markdown]
# ![image.png](attachment:c3932529-e06d-41a7-9295-50449be0747c.png)

# %% [markdown]
# ![image.png](attachment:53bc509b-fbfe-4273-8b22-be7cfd28fc6c.png)
