# %% [markdown]
# ## Sequence to Sequence model
# - encoding e decoding Network
# - Deep Translation

# %% [markdown]
# ![image.png](attachment:01b22786-96b8-4abc-9ed8-e0cda3f8abd9.png)

# %% [markdown]
# - Image Captioning
# ![image.png](attachment:f165dc56-f104-4f7d-99b9-34994c808189.png)

# %% [markdown]
# - Language Model (Probability of a sentence)
# - Machine Translation (Probability of a sentence give other sentence)
# ![image.png](attachment:d975654f-94f1-498b-9d3f-868b44ffcda6.png)

# %% [markdown]
# ![image.png](attachment:4a7212d3-df83-4e51-bd28-d44956135b9c.png)

# %% [markdown]
# ## Beam Search Algorithm

# %% [markdown]
# ![image.png](attachment:8a66fc9b-ad98-407c-ba04-1cbd9f26422b.png)

# %% [markdown]
# ![image.png](attachment:6e0c1f33-da03-401e-8893-2532ae93fbd5.png)

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# ![image.png](attachment:5496e15e-df97-4fb9-b7f9-55b9f3d4bae5.png)

# %% [markdown]
# ## Bleu Score - Machine Translation

# %% [markdown]
# ![image.png](attachment:51a41976-f804-47c6-924a-0d6a8280c0c9.png)

# %% [markdown]
# ## Attention Model

# %% [markdown]
# ![image.png](attachment:aef248f8-46bc-40b3-b885-3010006d8553.png)

# %% [markdown]
# ![image.png](attachment:7fcd0267-9aef-4d26-ace7-4992dd6696ff.png)

# %% [markdown]
# ![image.png](attachment:ad205125-6624-4685-b02b-362496a13d0c.png)

# %% [markdown]
# ![image.png](attachment:462e2bfa-b748-46ec-8c27-0c5cb65ad530.png)

# %% [markdown]
# ## Speech Recognition

# %% [markdown]
# ![image.png](attachment:13d5ef33-c1ca-474b-a789-11ec602f54b0.png)

# %% [markdown]
# ![image.png](attachment:7bae2caa-e2cf-4759-8140-5ebc8b499fd0.png)

# %% [markdown]
# ![image.png](attachment:a90236db-705f-4caa-b0f6-318a938e4d04.png)

# %% [markdown]
# ![image.png](attachment:a3876f8d-5d2d-47d8-9e46-ae126e5722be.png)

# %% [markdown]
# ![image.png](attachment:2a00fa2a-ee92-4343-9d2c-ce31f4f9e108.png)
