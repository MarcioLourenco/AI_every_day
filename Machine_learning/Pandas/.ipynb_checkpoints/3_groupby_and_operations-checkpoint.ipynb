# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('bank.csv')
df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df.groupby('job').agg({'duration':'mean'}).reset_index()
# Out:
#               job    duration
# 0          admin.  234.669456
# 1     blue-collar  278.161734
# 2    entrepreneur  285.476190
# 3       housemaid  292.633929
# 4      management  260.536636
# 5         retired  285.656522
# 6   self-employed  264.125683
# 7        services  262.486811
# 8         student  248.690476
# 9      technician  252.178385
# 10     unemployed  301.265625
# 11        unknown  216.921053

# %% [markdown]
# ## Operations

# %%
df = pd.DataFrame({'col1':[444, 555, 666], 'col2':[1., 2., 3.], 'col_3':['aaa', 'bbb', 'ccc']})
df
# Out:
#    col1  col2 col_3
# 0   444   1.0   aaa
# 1   555   2.0   bbb
# 2   666   3.0   ccc

# %%
df.head(2)
# Out:
#    col1  col2 col_3
# 0   444   1.0   aaa
# 1   555   2.0   bbb

# %%
df['col_3'].unique()
# Out:
# array(['aaa', 'bbb', 'ccc'], dtype=object)

# %%
df['col_3'].value_counts()
# Out:
# aaa    1
# bbb    1
# ccc    1
# Name: col_3, dtype: int64

# %%
def multiply_by_n(number):
    return number * 2

# %%
df["col2"].apply(multiply_by_n)
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# Name: col2, dtype: float64

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col_3'], dtype='object')

# %%
df.sort_values(by='col1', ascending=False)
# Out:
#    col1  col2 col_3
# 2   666   3.0   ccc
# 1   555   2.0   bbb
# 0   444   1.0   aaa
